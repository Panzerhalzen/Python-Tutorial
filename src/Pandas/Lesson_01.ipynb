# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Yes': [20, 40], 'No': [3, 10]})
df
# Out:
#    Yes  No
# 0   20   3
# 1   40  10

# %%
df = pd.DataFrame({
    'country': ["Казахстан", "Россия"],
    'population': [17.04, 143.5],
    'square': [2724902, 17125191],
    'leader': ['Назарбаев', 'Народ']
})
df
# Out:
#      country  population    square     leader
# 0  Казахстан       17.04   2724902  Назарбаев
# 1     Россия      143.50  17125191      Народ

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv('data/country.csv')

# %%
####################################

# %%
my_series = pd.Series(['Нижний Новгород', "Москва", "Кулебаки"])
my_series
# Out:
# 0    Нижний Новгород
# 1             Москва
# 2           Кулебаки
# dtype: object

# %%
my_series.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
my_series.values
# Out:
# array(['Нижний Новгород', 'Москва', 'Кулебаки'], dtype=object)

# %%
for i in my_series.values:
    print(i)
# Out:
# Нижний Новгород
# Москва
# Кулебаки

# %%
a = [i for i in my_series.values]
a
# Out:
# ['Нижний Новгород', 'Москва', 'Кулебаки']

# %%
my_series_2 = pd.Series([30, 35, 40, 0], index=['2015 sales', '2016 sales', '2017 sales', '2023 sales'])
my_series_2
# Out:
# 2015 sales    30
# 2016 sales    35
# 2017 sales    40
# 2023 sales     0
# dtype: int64

# %%
my_series_2[['2016 sales', '2023 sales']]
# Out:
# 2016 sales    35
# 2023 sales     0
# dtype: int64

# %%
my_series_2[['2016 sales', '2023 sales']] = 100, 66
my_series_2[['2016 sales', '2023 sales']]
# Out:
# 2016 sales    100
# 2023 sales     66
# dtype: int64

# %%
my_values = [i for i in my_series_2 if i > 70]
my_values
# Out:
# [100]

# %%
my_series_2[my_series_2 < 70]*2
# Out:
# 2015 sales     60
# 2017 sales     80
# 2023 sales    132
# dtype: int64

# %%
country = pd.Series(["Казахстан", "Россия"], name='country')
population = pd.Series([17.04, 143.5], name='population')
square = pd.Series([2724902, 17125191], name='square')
leader = pd.Series(['Назарбаев', 'Народ'], name='leader')

df = pd.DataFrame({
    'country': country,
    'population': population,
    'square': square,
    'leader': leader
})
df
# Out:
#      country  population    square     leader
# 0  Казахстан       17.04   2724902  Назарбаев
# 1     Россия      143.50  17125191      Народ

# %%
data = pd.read_csv('data/covid.csv')

# %%
data
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904     1,084,282          NaN
# 1      2           India   44,587,307       528,629          NaN
# 2      3          France   35,342,950       155,078          NaN
# 3      4          Brazil   34,706,757       686,027          NaN
# 4      5         Germany   33,312,373       149,948          NaN
# ..   ...             ...          ...           ...          ...
# 225  226            Niue           80           NaN          NaN
# 226  227    Vatican City           29           NaN          NaN
# 227  228          Tuvalu           20           NaN          NaN
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
columns = ['id', 'Country', 'Total cases', 'TotalDeaths', 'NewDeaths', 'Total Recovered', 
           'Active', 'Serious or Critical Cases', 'Total Cases / 1M pop', 'Total Deaths / 1M pop', 'Total tests', 'Total tests / 1M pop', 'Population']
len(columns)
# Out:
# 13

# %%
data.columns = columns

# %%
data
# Out:
#       id         Country Total cases TotalDeaths  NewDeaths Total Recovered  \
# 0      1             USA  98,166,904   1,084,282        NaN      94,962,112
# 1      2           India  44,587,307     528,629        NaN      44,019,095
# 2      3          France  35,342,950     155,078        NaN      34,527,115
# 3      4          Brazil  34,706,757     686,027        NaN      33,838,636
# 4      5         Germany  33,312,373     149,948        NaN      32,315,200
# ..   ...             ...         ...         ...        ...             ...
# 225  226            Niue          80         NaN        NaN              80
# 226  227    Vatican City          29         NaN        NaN              29
# 227  228          Tuvalu          20         NaN        NaN             NaN
# 228  229  Western Sahara          10           1        NaN               9
# 229  230      MS Zaandam           9           2        NaN               7
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'Country', 'Total cases', 'TotalDeaths', 'NewDeaths',
#        'Total Recovered', 'Active', 'Serious or Critical Cases',
#        'Total Cases / 1M pop', 'Total Deaths / 1M pop', 'Total tests',
#        'Total tests / 1M pop', 'Population'],
#       dtype='object')

# %%
data.head(7)
# Out:
#    id   Country Total cases TotalDeaths  NewDeaths Total Recovered     Active  \
# 0   1       USA  98,166,904   1,084,282        NaN      94,962,112  2,120,510
# 1   2     India  44,587,307     528,629        NaN      44,019,095     39,583
# 2   3    France  35,342,950     155,078        NaN      34,527,115    660,757
# 3   4    Brazil  34,706,757     686,027        NaN      33,838,636    182,094
# 4   5   Germany  33,312,373     149,948        NaN      32,315,200    847,225
# 5   6  S. Korea  24,769,101      28,406       42.0      24,013,461    727,234
# 6   7        UK  23,621,952     189,919        NaN      23,347,871     84,162
#
#   Serious or Critical Cases Total Cases / 1M pop Total Deaths / 1M pop  \
# 0                     2,970              293,206                 3,239
# 1                       698               31,698                   376
# 2                       869              538,892                 2,365
# ...

# %%
data.shape
# Out:
# (230, 13)

# %%
data.size
# Out:
# 2990

# %%
data['NewDeaths'] = data['NewDeaths'].fillna('--')

# %%
data.head(9)
# Out:
#    id   Country Total cases TotalDeaths NewDeaths Total Recovered     Active  \
# 0   1       USA  98,166,904   1,084,282        --      94,962,112  2,120,510
# 1   2     India  44,587,307     528,629        --      44,019,095     39,583
# 2   3    France  35,342,950     155,078        --      34,527,115    660,757
# 3   4    Brazil  34,706,757     686,027        --      33,838,636    182,094
# 4   5   Germany  33,312,373     149,948        --      32,315,200    847,225
# 5   6  S. Korea  24,769,101      28,406      42.0      24,013,461    727,234
# 6   7        UK  23,621,952     189,919        --      23,347,871     84,162
# 7   8     Italy  22,432,803     177,054        --      21,779,604    476,145
# 8   9     Japan  21,229,216      44,678        --      20,380,089    804,449
#
#   Serious or Critical Cases Total Cases / 1M pop Total Deaths / 1M pop  \
# 0                     2,970              293,206                 3,239
# ...
